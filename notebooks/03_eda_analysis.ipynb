# %%
import warnings
warnings.filterwarnings('ignore')
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

BASE  = Path.cwd().parent
RAW   = BASE / 'data' / 'raw'
FIGS  = BASE / 'reports'
FIGS.mkdir(exist_ok=True)

sns.set_theme(style='darkgrid')
plt.rcParams.update({'figure.dpi':120, 'figure.figsize':(12,5)})

nav   = pd.read_csv(RAW/'02_nav_history.csv')
nav['date'] = pd.to_datetime(nav['date'])
aum   = pd.read_csv(RAW/'03_aum_by_fund_house.csv')
sip   = pd.read_csv(RAW/'04_monthly_sip_inflows.csv')
cat   = pd.read_csv(RAW/'05_category_inflows.csv')
fol   = pd.read_csv(RAW/'06_industry_folio_count.csv')
tx    = pd.read_csv(RAW/'08_investor_transactions.csv')
port  = pd.read_csv(RAW/'09_portfolio_holdings.csv')
fm    = pd.read_csv(RAW/'01_fund_master.csv')
bench = pd.read_csv(RAW/'10_benchmark_indices.csv')
nav   = nav.merge(fm[['amfi_code','scheme_name','sub_category','fund_house']], on='amfi_code', how='left')
print('All datasets loaded!')
# Out:
# Matplotlib is building the font cache; this may take a moment.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7676 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 'date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 21
#      17 sns.set_theme(style='darkgrid')
#      18 plt.rcParams.update({'figure.dpi':120, 'figure.figsize':(12,5)})
#      19
#      20 nav   = pd.read_csv(RAW/'02_nav_history.csv')
# ---> 21 nav['date'] = pd.to_datetime(nav['date'])
#      22 aum   = pd.read_csv(RAW/'03_aum_by_fund_house.csv')
#      23 sip   = pd.read_csv(RAW/'04_monthly_sip_inflows.csv')
#      24 cat   = pd.read_csv(RAW/'05_category_inflows.csv')
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:4378, in DataFrame.__getitem__(self, key)
#    4374
#    4375         if is_single_key:
#    4376             if self.columns.nlevels > 1:
#    4377                 return self._getitem_multilevel(key)
# -> 4378             indexer = self.columns.get_loc(key)
#    4379             if is_integer(indexer):
#    4380                 indexer = [indexer]
#    4381         else:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'date'

# %%
# Chart 1 - NAV Trend Lines
aum['year'] = aum['quarter'].dt.year
aum_yr = aum.groupby(['fund_house','year'])['aum_crore'].max().reset_index()
aum_yr['aum_lakh_cr'] = aum_yr['aum_crore'] / 100000

fig, ax = plt.subplots(figsize=(14,6))
fh_order = aum_yr.groupby('fund_house')['aum_lakh_cr'].max().sort_values(ascending=False).index
sns.barplot(data=aum_yr, x='fund_house', y='aum_lakh_cr', hue='year', order=fh_order, palette='Blues', ax=ax)
ax.set_xticklabels([x.replace(' Mutual Fund','').replace(' Prudential','') for x in fh_order], rotation=30, ha='right')
ax.set_title('AUM Growth by Fund House 2022–2025 (₹ Lakh Crore)', fontsize=14, fontweight='bold')
ax.set_xlabel('Fund House')
ax.set_ylabel('AUM (₹ Lakh Crore)')
ax.axhline(y=12.5, color='red', linestyle='--', alpha=0.6, label='SBI ₹12.5L Cr')
ax.legend(title='Year', bbox_to_anchor=(1.01,1))
plt.tight_layout()
plt.savefig(FIGS/'chart1_aum_growth.png', dpi=120, bbox_inches='tight')
plt.show()
print('Chart 1 saved!')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Chart 1 - NAV Trend Lines
# ----> 2 aum['year'] = aum['quarter'].dt.year
#       3 aum_yr = aum.groupby(['fund_house','year'])['aum_crore'].max().reset_index()
#       4 aum_yr['aum_lakh_cr'] = aum_yr['aum_crore'] / 100000
#       5
#
# NameError: name 'aum' is not defined

# %%
import warnings
warnings.filterwarnings('ignore')
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

# Fix path — use absolute path
RAW   = Path(r'C:\Users\ajays\bluestock_mf_capstone\data\raw')
FIGS  = Path(r'C:\Users\ajays\bluestock_mf_capstone\reports')
FIGS.mkdir(exist_ok=True)

sns.set_theme(style='darkgrid')
plt.rcParams.update({'figure.dpi':120, 'figure.figsize':(12,5)})

nav   = pd.read_csv(RAW/'02_nav_history.csv')
nav['date'] = pd.to_datetime(nav['date'])
aum   = pd.read_csv(RAW/'03_aum_by_fund_house.csv')
aum['quarter'] = pd.to_datetime(aum['quarter'])
sip   = pd.read_csv(RAW/'04_monthly_sip_inflows.csv')
cat   = pd.read_csv(RAW/'05_category_inflows.csv')
fol   = pd.read_csv(RAW/'06_industry_folio_count.csv')
tx    = pd.read_csv(RAW/'08_investor_transactions.csv')
port  = pd.read_csv(RAW/'09_portfolio_holdings.csv')
fm    = pd.read_csv(RAW/'01_fund_master.csv')
bench = pd.read_csv(RAW/'10_benchmark_indices.csv')
bench['date'] = pd.to_datetime(bench['date'])
nav   = nav.merge(fm[['amfi_code','scheme_name','sub_category','fund_house']], on='amfi_code', how='left')
print('✅ All datasets loaded!')
print('NAV shape:', nav.shape)




import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from pathlib import Path

# Hard-coded absolute path — no relative path issues
RAW  = Path(r'C:\Users\ajays\bluestock_mf_capstone\data\raw')
FIGS = Path(r'C:\Users\ajays\bluestock_mf_capstone\reports')
FIGS.mkdir(exist_ok=True)

sns.set_theme(style='darkgrid')
plt.rcParams.update({'figure.dpi':120, 'figure.figsize':(12,5)})

nav   = pd.read_csv(RAW / '02_nav_history.csv')
nav['date'] = pd.to_datetime(nav['date'])
aum   = pd.read_csv(RAW / '03_aum_by_fund_house.csv')
aum['quarter'] = pd.to_datetime(aum['quarter'])
sip   = pd.read_csv(RAW / '04_monthly_sip_inflows.csv')
cat   = pd.read_csv(RAW / '05_category_inflows.csv')
fol   = pd.read_csv(RAW / '06_industry_folio_count.csv')
tx    = pd.read_csv(RAW / '08_investor_transactions.csv')
port  = pd.read_csv(RAW / '09_portfolio_holdings.csv')
fm    = pd.read_csv(RAW / '01_fund_master.csv')
bench = pd.read_csv(RAW / '10_benchmark_indices.csv')
bench['date'] = pd.to_datetime(bench['date'])
nav   = nav.merge(fm[['amfi_code','scheme_name','sub_category','fund_house']], on='amfi_code', how='left')

print('✅ All datasets loaded!')
print('NAV shape:', nav.shape)
print('Columns:', nav.columns.tolist())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7676 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 'date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 21
#      17 sns.set_theme(style='darkgrid')
#      18 plt.rcParams.update({'figure.dpi':120, 'figure.figsize':(12,5)})
#      19
#      20 nav   = pd.read_csv(RAW/'02_nav_history.csv')
# ---> 21 nav['date'] = pd.to_datetime(nav['date'])
#      22 aum   = pd.read_csv(RAW/'03_aum_by_fund_house.csv')
#      23 aum['quarter'] = pd.to_datetime(aum['quarter'])
#      24 sip   = pd.read_csv(RAW/'04_monthly_sip_inflows.csv')
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:4378, in DataFrame.__getitem__(self, key)
#    4374
#    4375         if is_single_key:
#    4376             if self.columns.nlevels > 1:
#    4377                 return self._getitem_multilevel(key)
# -> 4378             indexer = self.columns.get_loc(key)
#    4379             if is_integer(indexer):
#    4380                 indexer = [indexer]
#    4381         else:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'date'

# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from pathlib import Path

RAW  = Path(r'C:\Users\ajays\bluestock_mf_capstone\data\raw')
FIGS = Path(r'C:\Users\ajays\bluestock_mf_capstone\reports')
FIGS.mkdir(exist_ok=True)

sns.set_theme(style='darkgrid')
plt.rcParams.update({'figure.dpi':120, 'figure.figsize':(12,5)})

nav   = pd.read_csv(RAW / '02_nav_history.csv')
nav['date'] = pd.to_datetime(nav['date'])
aum   = pd.read_csv(RAW / '03_aum_by_fund_house.csv')
aum['quarter'] = pd.to_datetime(aum['quarter'])
sip   = pd.read_csv(RAW / '04_monthly_sip_inflows.csv')
cat   = pd.read_csv(RAW / '05_category_inflows.csv')
fol   = pd.read_csv(RAW / '06_industry_folio_count.csv')
tx    = pd.read_csv(RAW / '08_investor_transactions.csv')
port  = pd.read_csv(RAW / '09_portfolio_holdings.csv')
fm    = pd.read_csv(RAW / '01_fund_master.csv')
bench = pd.read_csv(RAW / '10_benchmark_indices.csv')
bench['date'] = pd.to_datetime(bench['date'])
nav   = nav.merge(fm[['amfi_code','scheme_name','sub_category','fund_house']], on='amfi_code', how='left')
aum['year'] = aum['quarter'].dt.year

print('✅ All datasets loaded!')
print('NAV shape:', nav.shape)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7676 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 'date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 20
#      16 sns.set_theme(style='darkgrid')
#      17 plt.rcParams.update({'figure.dpi':120, 'figure.figsize':(12,5)})
#      18
#      19 nav   = pd.read_csv(RAW / '02_nav_history.csv')
# ---> 20 nav['date'] = pd.to_datetime(nav['date'])
#      21 aum   = pd.read_csv(RAW / '03_aum_by_fund_house.csv')
#      22 aum['quarter'] = pd.to_datetime(aum['quarter'])
#      23 sip   = pd.read_csv(RAW / '04_monthly_sip_inflows.csv')
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:4378, in DataFrame.__getitem__(self, key)
#    4374
#    4375         if is_single_key:
#    4376             if self.columns.nlevels > 1:
#    4377                 return self._getitem_multilevel(key)
# -> 4378             indexer = self.columns.get_loc(key)
#    4379             if is_integer(indexer):
#    4380                 indexer = [indexer]
#    4381         else:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'date'
